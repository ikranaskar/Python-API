# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 596

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response = requests.get(city_url)
        response = response.json()
        response
        city_weather = response['weather'][0]["main"]

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response['coord']['lat']
        city_lng = response['coord']['lon']
        city_max_temp = response['main']['temp_max']
        city_humidity =response['main']['humidity']
        city_clouds = response['clouds']['all']
        city_wind = response['wind']['speed']
        city_country = response['sys']['country']
        city_date = city_date = response['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | avera
# Processing Record 2 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 1 | ulladulla
# Processing Record 4 of Set 1 | ranfurly
# Processing Record 5 of Set 1 | elmira
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | ancud
# Processing Record 9 of Set 1 | dalbandin
# Processing Record 10 of Set 1 | broome
# Processing Record 11 of Set 1 | darhan
# Processing Record 12 of Set 1 | avarua
# Processing Record 13 of Set 1 | tiksi
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | ust-nera
# Processing Record 16 of Set 1 | souillac
# Processing Record 17 of Set 1 | cherskiy
# Processing Record 18 of Set 1 | sur
# Processing Record 19 of Set 1 | namibe
# Processing Record 20 of Set 1 | tuktoyaktuk
# Processing Record 21 of Set 1 | raichur
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_df = pd.DataFrame(city_data)

# Show Record Count
city_df.count()

# %%
# Display sample data
city_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      avera  33.1940  -82.5271     78.85        57          75       11.59
# 1  ulladulla -35.3500  150.4667     59.77        88          96        3.40
# 2   ranfurly -45.1333  170.1000     50.11        99         100        1.34
# 3     elmira  42.0898  -76.8077     43.99        94         100       15.68
# 4    ushuaia -54.8000  -68.3000     53.26        50          75        5.75
#
#   Country        Date
# 0      US  1679775927
# 1      AU  1679775928
# 2      NZ  1679775928
# 3      US  1679775784
# 4      AR  1679775803

# %%
# Export the City_Data into a csv
city_df.to_csv("output_city_data.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_city_data.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            avera  33.1940  -82.5271     78.85        57          75
# 1        ulladulla -35.3500  150.4667     59.77        88          96
# 2         ranfurly -45.1333  170.1000     50.11        99         100
# 3           elmira  42.0898  -76.8077     43.99        94         100
# 4          ushuaia -54.8000  -68.3000     53.26        50          75
#
#          Wind Speed Country        Date
# City_ID
# 0             11.59      US  1679775927
# 1              3.40      AU  1679775928
# 2              1.34      NZ  1679775928
# 3             15.68      US  1679775784
# 4              5.75      AR  1679775803

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x = city_data_df["Lat"]
y = city_data_df["Max Temp"]
plt.scatter(x,y)
plt.title("City Latitude vs Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.grid()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x = city_data_df["Lat"]
y = city_data_df["Humidity"]
plt.scatter(x,y)
plt.title("City Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()
# Save the figure
plt.savefig("Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x = city_data_df["Lat"]
y = city_data_df["Cloudiness"]
plt.scatter(x,y)
plt.title("City Latitude vs cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()
# Save the figure
plt.savefig("Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x = city_data_df["Lat"]
y = city_data_df["Wind Speed"]
plt.scatter(x,y)
plt.title("City Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()

# Save the figure
plt.savefig("Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            avera  33.1940  -82.5271     78.85        57          75
# 3           elmira  42.0898  -76.8077     43.99        94         100
# 7        dalbandin  28.8947   64.4101     64.99        32           0
# 8           broome  42.2506  -75.8330     41.45        83         100
# 9           darhan  49.4867  105.9228     14.11        89         100
#
#          Wind Speed Country        Date
# City_ID
# 0             11.59      US  1679775927
# 3             15.68      US  1679775784
# 7              4.79      PK  1679775930
# 8             18.41      US  1679775930
# 9              5.19      MN  1679775931

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        ulladulla -35.3500  150.4667     59.77        88          96
# 2         ranfurly -45.1333  170.1000     50.11        99         100
# 4          ushuaia -54.8000  -68.3000     53.26        50          75
# 5          rikitea -23.1203 -134.9692     76.91        82         100
# 6            ancud -41.8697  -73.8203     58.80        55           0
#
#          Wind Speed Country        Date
# City_ID
# 1              3.40      AU  1679775928
# 2              1.34      NZ  1679775928
# 4              5.75      AR  1679775803
# 5              7.38      PF  1679775894
# 6              3.56      CL  1679775929

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_axis = northern_hemi_df['Lat']
y_axis = northern_hemi_df['Max Temp']

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_axis,y_axis)
regress_values = x_axis*slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.annotate(line_eq,(0,0),fontsize=12,color="red",fontweight="bold")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7908628546674683

# %%
# Linear regression on Southern Hemisphere
linear_regression = linregress(south['Lat'], south['Max Temp'])
linear_equation = linear_regression[0] * south['Lat'] + linear_regression[1]
line_eq = f'y = {str(round(linear_regression[0],2))} x + {str(round(linear_regression[1],2))}'

print(f'The r-squared is: {round(linear_regression[2],3)}')
south.plot.scatter(
    x = 'Lat',
    y = 'Max Temp',)
    

plt.plot(
    south['Lat'],
    linear_equation,
    linewidth = 3,
    color = 'black')

plt.title('Southern Hemisphere: City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature Celcius')
plt.annotate(line_eq,(50,20),fontsize=12,color="green",fontweight="bold")
plt.show()
# Out:
# The r-squared is: 0.681

# %% [markdown]
# **Discussion about the linear relationship:** The positive slope of the linear regression line for both hemispheres indicates that as latitude increases (moving further away from the equator), temperature tends to decrease. For ex. Colder in northern and warmer in Southern

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = northern_hemi_df['Lat']
y_axis = northern_hemi_df['Humidity']

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_axis,y_axis)
regress_values = x_axis*slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq,(50,20),fontsize=12,color="red",fontweight="bold")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.10223429147623642

# %%
# Southern Hemisphere
x_axis = southern_hemi_df['Lat']
y_axis = southern_hemi_df['Humidity']

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_axis,y_axis)
regress_values = x_axis*slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_axis,y_axis,color="orange")
plt.plot(x_axis,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq,(-20,20),fontsize=12,color="blue",fontweight="bold")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.04695602174362463

# %% [markdown]
# **Discussion about the linear relationship:** The humidity for the southern hemisphere appears to be higher

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = northern_hemi_df['Lat']
y_axis = northern_hemi_df['Cloudiness']

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_axis,y_axis)
regress_values = x_axis*slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq,(50,35),fontsize=12,color="red",fontweight="bold")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.08507048828802345

# %%
# Southern Hemisphere
x_axis = southern_hemi_df['Lat']
y_axis = southern_hemi_df['Cloudiness']

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_axis,y_axis)
regress_values = x_axis*slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_axis,y_axis,color="orange")
plt.plot(x_axis,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq,(-55,5),fontsize=12,color="blue",fontweight="bold")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.06919371072253858

# %% [markdown]
# **Discussion about the linear relationship:** Cloudiness is slightly higher in the northern hemisphere

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = northern_hemi_df['Lat']
y_axis = northern_hemi_df['Wind Speed']

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_axis,y_axis)
regress_values = x_axis*slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(line_eq,(10,30),fontsize=12,color="red",fontweight="bold")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.004199408408132192

# %%
# Southern Hemisphere
x_axis = southern_hemi_df['Lat']
y_axis = southern_hemi_df['Wind Speed']

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_axis,y_axis)
regress_values = x_axis*slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_axis,y_axis,color="orange")
plt.plot(x_axis,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(line_eq,(-50,20),fontsize=12,color="blue",fontweight="bold")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.05306524964409847

# %% [markdown]
# **Discussion about the linear relationship:** The higher r-squared value suggests that the windspeed association is marginally greater in the southern hemisphere than in the northern hemisphere.
